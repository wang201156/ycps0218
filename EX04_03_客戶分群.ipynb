# %% [markdown]
# <a href="https://colab.research.google.com/github/wang201156/ycps0218/blob/main/EX04_03_%E5%AE%A2%E6%88%B6%E5%88%86%E7%BE%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 問題定義

# %% [markdown]
# 將 性別 欄位 Label Encoding
# 將客戶分成 3 群，並解讀各群特質
# 計算 k = 2 ~ 15 的 Calinski-Harbasz Score，找出最佳 k 值

# %% [markdown]
# ## 資料收集

# %%
# !wget -O car_models.csv https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv
# Out:
# --2025-05-27 07:35:30--  https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2839 (2.8K) [text/plain]
# Saving to: ‘car_models.csv’
#
# car_models.csv      100%[===================>]   2.77K  --.-KB/s    in 0s
#
# 2025-05-27 07:35:30 (35.8 MB/s) - ‘car_models.csv’ saved [2839/2839]

# %% [markdown]
# ## 資料前處理

# %%
import pandas as pd
df=pd.read_csv("car_models.csv")
df
# Out:
#     性別  年齡  收入（千）  消費指數（1~100）
# 0    女  74     38           81
# 1    女  51     71           91
# 2    女  30     65           10
# 3    女  88     49           17
# 4    女  55     48           70
# ..  ..  ..    ...          ...
# 195  男  86     84           82
# 196  男  59     52           30
# 197  女  63     29           61
# 198  男  67     80            9
# 199  男  72     69           92
#
# [200 rows x 4 columns]

# %% [markdown]
# ### 資料清理

# %% [markdown]
# ### 探索性分析

# %% [markdown]
# ### 資料分割(分群不資料分割)

# %% [markdown]
# ### 類別轉換

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[["女","男"]])
df[["性別"]] = encoder.fit_transform(df[["性別"]])
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）
# 0    0.0  74     38           81
# 1    0.0  51     71           91
# 2    0.0  30     65           10
# 3    0.0  88     49           17
# 4    0.0  55     48           70
# ..   ...  ..    ...          ...
# 195  1.0  86     84           82
# 196  1.0  59     52           30
# 197  0.0  63     29           61
# 198  1.0  67     80            9
# 199  1.0  72     69           92
#
# [200 rows x 4 columns]

# %% [markdown]
# ### 特徵縮放

# %% [markdown]
# ## 模型訓練

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
# 為每筆資料加上分群結果
df['cluster'] = kmeans.labels_
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）  cluster
# 0    0.0  74     38           81        2
# 1    0.0  51     71           91        2
# 2    0.0  30     65           10        0
# 3    0.0  88     49           17        0
# 4    0.0  55     48           70        2
# ..   ...  ..    ...          ...      ...
# 195  1.0  86     84           82        2
# 196  1.0  59     52           30        0
# 197  0.0  63     29           61        2
# 198  1.0  67     80            9        0
# 199  1.0  72     69           92        2
#
# [200 rows x 5 columns]

# %% [markdown]
# ## 模型評估

# %%
# 查看各群特質
df.groupby('cluster').mean()
# Out:
#                性別         年齡      收入（千）  消費指數（1~100）
# cluster
# 0        0.582278  56.683544  61.518987    20.696203
# 1        0.574074  28.740741  54.685185    71.203704
# 2        0.552239  67.641791  58.985075    75.104478

# %%
# 評估分群效果
from sklearn.metrics import calinski_harabasz_score
score = calinski_harabasz_score(df, kmeans.labels_)
score
# Out:
# np.float64(89.38724632933332)

# %% [markdown]
# ## 模型調整

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score
df_nocluster = df.drop(columns=['cluster'])
for i in range(2,16):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(df_nocluster)
  score = calinski_harabasz_score(df, kmeans.labels_)
  print(f"k={i}",score)
# Out:
# k=2 111.75107356253265
# k=3 95.38770849826643
# k=4 81.97651637746381
# k=5 89.10298540180835
# k=6 88.03161436892663
# k=7 93.4756523001948
# k=8 90.47719156333905
# k=9 96.52895909909316
# k=10 93.64522807871117
# k=11 89.92567552521945
# k=12 87.03110684805044
# k=13 88.40541187139657
# k=14 82.46215420530883
# k=15 82.68189769473196

# %% [markdown]
# ## 模型部署

# %% [markdown]
# ### 儲存模型

# %% [markdown]
# ### 推論預測
