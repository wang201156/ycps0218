# %% [markdown]
# <a href="https://colab.research.google.com/github/wang201156/ycps0218/blob/main/EX03_01_%E5%85%AC%E5%8F%B8%E8%96%AA%E8%B3%87%E6%A6%82%E6%B3%81%E2%85%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Helen', 'Ivy', 'Jack'],
    'Age': [25, 30, 35, 40, 22, 29, 38, 27, 33, 31],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose'],
    'Salary': [50000, 60000, 75000, 80000, 45000, 62000, 72000, 58000, 69000, 71000],
    'Department': ['IT', 'HR', 'Finance', 'Marketing', 'IT', 'HR', 'Finance', 'Marketing', 'IT', 'Finance']
}
df = pd.DataFrame(data)
df
# Out:
#     ID     Name  Age          City  Salary Department
# 0  101    Alice   25      New York   50000         IT
# 1  102      Bob   30   Los Angeles   60000         HR
# 2  103  Charlie   35       Chicago   75000    Finance
# 3  104    David   40       Houston   80000  Marketing
# 4  105      Eve   22       Phoenix   45000         IT
# 5  106    Frank   29  Philadelphia   62000         HR
# 6  107    Grace   38   San Antonio   72000    Finance
# 7  108    Helen   27     San Diego   58000  Marketing
# 8  109      Ivy   33        Dallas   69000         IT
# 9  110     Jack   31      San Jose   71000    Finance

# %%
df[[  "Name","Salary" ]]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   75000
# 3    David   80000
# 4      Eve   45000
# 5    Frank   62000
# 6    Grace   72000
# 7    Helen   58000
# 8      Ivy   69000
# 9     Jack   71000

# %%
df.iloc[5:9,:]
# Out:
#     ID   Name  Age          City  Salary Department
# 5  106  Frank   29  Philadelphia   62000         HR
# 6  107  Grace   38   San Antonio   72000    Finance
# 7  108  Helen   27     San Diego   58000  Marketing
# 8  109    Ivy   33        Dallas   69000         IT

# %%
age_m=df["Age"].mean()
sal_m=df["Salary"].mean()
condition = (df['Age'] > age_m) & (df['Salary'] > sal_m)
df[condition]
# Out:
#     ID     Name  Age         City  Salary Department
# 2  103  Charlie   35      Chicago   75000    Finance
# 3  104    David   40      Houston   80000  Marketing
# 6  107    Grace   38  San Antonio   72000    Finance
# 8  109      Ivy   33       Dallas   69000         IT

# %%
print("平均:",  df['Salary'].mean() )
print("最高:",  df['Salary'].max()  )
print("最低:",  df['Salary'].min()  )
print("中位數:", df['Salary'].median() )
# Out:
# 平均: 64200.0
# 最高: 80000
# 最低: 45000
# 中位數: 65500.0

# %%
print("部門:",  df['Department'].unique() )
df_gp = df.groupby('Department')
print("部門薪水最高:", df_gp['Salary'].mean().idxmax())
print("那個部門最年輕:", df_gp['Age'].mean().idxmin())
# Out:
# 部門: ['IT' 'HR' 'Finance' 'Marketing']
# 部門薪水最高: Finance
# 那個部門最年輕: IT

# %%
df[['Age', 'Salary']].corr()
# Out:
#              Age    Salary
# Age     1.000000  0.949344
# Salary  0.949344  1.000000

# %% [markdown]
# Q:年齡是否與薪資有關？
# A:有
